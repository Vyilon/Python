# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Airline_Delay_cause.csv")

# %%
data.describe()
# Out:
#                 year          month    arr_flights      arr_del15  \
# count  318017.000000  318017.000000  317529.000000  317289.000000
# mean     2012.450957       6.497844     381.763984      72.904403
# std         5.678296       3.459423    1027.148994     198.935595
# min      2003.000000       1.000000       1.000000       0.000000
# 25%      2007.000000       3.000000      59.000000       9.000000
# 50%      2012.000000       6.000000     120.000000      23.000000
# 75%      2018.000000      10.000000     273.000000      56.000000
# max      2022.000000      12.000000   21977.000000    6377.000000
#
#           carrier_ct     weather_ct         nas_ct    security_ct  \
# count  317529.000000  317529.000000  317529.000000  317529.000000
# mean       21.072980       2.616379      24.005228       0.179037
# std        47.671306       9.968549      85.113757       0.844834
# min         0.000000       0.000000      -0.010000       0.000000
# ...

# %%
sns.scatterplot(data=data, x='arr_flights',y='arr_del15', hue='weather_ct')
# Out:
# <AxesSubplot:xlabel='arr_flights', ylabel='arr_del15'>

# %%
data.corr()
# Out:
#                          year     month  arr_flights  arr_del15  carrier_ct  \
# year                 1.000000 -0.072363    -0.025699  -0.052957   -0.035570
# month               -0.072363  1.000000     0.003852  -0.000387    0.002263
# arr_flights         -0.025699  0.003852     1.000000   0.918808    0.883630
# arr_del15           -0.052957 -0.000387     0.918808   1.000000    0.908627
# carrier_ct          -0.035570  0.002263     0.883630   0.908627    1.000000
# weather_ct          -0.061241 -0.012914     0.613742   0.666306    0.692905
# nas_ct              -0.066217 -0.001083     0.807462   0.920773    0.734855
# security_ct         -0.042988  0.009947     0.473536   0.484547    0.506949
# late_aircraft_ct    -0.034567  0.000819     0.868245   0.931671    0.838892
# arr_cancelled        0.009889 -0.049273     0.499151   0.517991    0.463856
# arr_diverted        -0.008427 -0.004105     0.637867   0.668901    0.594386
# ...

# %%
sns.set(rc = {'figure.figsize':(15,15)})
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=data, x='arr_flights',y='arr_del15', hue='weather_ct')
# Out:
# <AxesSubplot:xlabel='arr_flights', ylabel='arr_del15'>

# %%
ax = sns.boxplot(data=data, x='year',y='carrier_delay')
ax.set(ylim=(0, 4000))
# Out:
# [(0.0, 4000.0)]
