# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv("Airline_Delay_cause.csv")

# %%
print(data.head())
print(data.describe())
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE
# 1  2022      5      9E  Endeavor Air Inc.     ABY
# 2  2022      5      9E  Endeavor Air Inc.     ACK
# 3  2022      5      9E  Endeavor Air Inc.     AEX
# 4  2022      5      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0        7.0
# 1             Albany, GA: Southwest Georgia Regional         91.0       16.0
# 2                  Nantucket, MA: Nantucket Memorial         19.0        2.0
# 3           Alexandria, LA: Alexandria International         88.0       14.0
# 4        Augusta, GA: Augusta Regional at Bush Field        181.0       19.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        5.95        0.00  ...          0.0              1.00            0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318017 entries, 0 to 318016
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 318017 non-null  int64
#  1   month                318017 non-null  int64
#  2   carrier              318017 non-null  object
#  3   carrier_name         318017 non-null  object
#  4   airport              318017 non-null  object
#  5   airport_name         318017 non-null  object
#  6   arr_flights          317529 non-null  float64
#  7   arr_del15            317289 non-null  float64
#  8   carrier_ct           317529 non-null  float64
#  9   weather_ct           317529 non-null  float64
#  10  nas_ct               317529 non-null  float64
#  11  security_ct          317529 non-null  float64
#  12  late_aircraft_ct     317529 non-null  float64
#  13  arr_cancelled        317529 non-null  float64
# ...

# %%
data.shape
# Out:
# (318017, 21)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['airport_name'].unique()
# Out:
# array(['Allentown/Bethlehem/Easton, PA: Lehigh Valley International',
#        'Albany, GA: Southwest Georgia Regional',
#        'Nantucket, MA: Nantucket Memorial',
#        'Alexandria, LA: Alexandria International',
#        'Augusta, GA: Augusta Regional at Bush Field',
#        'Albany, NY: Albany International',
#        'Atlanta, GA: Hartsfield-Jackson Atlanta International',
#        'Appleton, WI: Appleton International',
#        'Austin, TX: Austin - Bergstrom International',
#        'Asheville, NC: Asheville Regional',
#        'Kalamazoo, MI: Kalamazoo/Battle Creek International',
#        'Binghamton, NY: Greater Binghamton/Edwin A. Link Field',
#        'Bangor, ME: Bangor International',
#        'Birmingham, AL: Birmingham-Shuttlesworth International',
#        'Bloomington/Normal, IL: Central Il Regional Airport at Bloomington',
#        'Nashville, TN: Nashville International',
#        'Boston, MA: Logan International',
# ...

# %%
data.corr()
# Out:
#                          year     month  arr_flights  arr_del15  carrier_ct  \
# year                 1.000000 -0.072363    -0.025699  -0.052957   -0.035570
# month               -0.072363  1.000000     0.003852  -0.000387    0.002263
# arr_flights         -0.025699  0.003852     1.000000   0.918808    0.883630
# arr_del15           -0.052957 -0.000387     0.918808   1.000000    0.908627
# carrier_ct          -0.035570  0.002263     0.883630   0.908627    1.000000
# weather_ct          -0.061241 -0.012914     0.613742   0.666306    0.692905
# nas_ct              -0.066217 -0.001083     0.807462   0.920773    0.734855
# security_ct         -0.042988  0.009947     0.473536   0.484547    0.506949
# late_aircraft_ct    -0.034567  0.000819     0.868245   0.931671    0.838892
# arr_cancelled        0.009889 -0.049273     0.499151   0.517991    0.463856
# arr_diverted        -0.008427 -0.004105     0.637867   0.668901    0.594386
# ...

# %%
data[data['weather_delay'] > 1000][['airport_name', 'carrier_name', 'month']].head(25)
# Out:
#                                           airport_name  \
# 6    Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 56         New York, NY: John F. Kennedy International
# 60                             New York, NY: LaGuardia
# 80    Raleigh/Durham, NC: Raleigh-Durham International
# 103       Austin, TX: Austin - Bergstrom International
# 109                    Boston, MA: Logan International
# 116     Charlotte, NC: Charlotte Douglas International
# 120  Washington, DC: Ronald Reagan Washington National
# 122  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...
# 142        New York, NY: John F. Kennedy International
# 145         Los Angeles, CA: Los Angeles International
# 147                            New York, NY: LaGuardia
# 151                 Orlando, FL: Orlando International
# 155                     Miami, FL: Miami International
# 166          Chicago, IL: Chicago O'Hare International
# 170       Philadelphia, PA: Philadelphia International
# ...

# %%
a = np.array([[1, -2, 4], [2, 0, -1]])
b = np.array([[5, 2, 3], [4, 6, 2]])
a + b
# Out:
# array([[6, 0, 7],
#        [6, 6, 1]])

# %%
a - b
# Out:
# array([[-4, -4,  1],
#        [-2, -6, -3]])

# %%
a2 = np.array([[1, 2],[2, -1],[3, 0]])
b2 = np.array([[-1, 1],[1, 2],[0, 0]])
c2 = a2 -3*b2
c2
# Out:
# array([[ 4, -1],
#        [-1, -7],
#        [ 3,  0]])

# %%
a3 = np.array([[1, -1],[2, 0],[3, 0]])
b3 = np.array([[1, 1],[2, 0]])
c3 = a3 @ b3
c3
# Out:
# array([[-1,  1],
#        [ 2,  2],
#        [ 3,  3]])

# %%
a4 = np.array([[6, -1, 4],[2, 1, 10],[8, 0, 2]])

np.linalg.det(a4)
# Out:
# -95.99999999999999

# %%
a5 = np.array([[3, 3, -1],[4, 1, 3],[1, -2, -2]])
b5 = np.linalg.inv(a5)
b5
# Out:
# array([[ 0.07407407,  0.14814815,  0.18518519],
#        [ 0.2037037 , -0.09259259, -0.24074074],
#        [-0.16666667,  0.16666667, -0.16666667]])

# %%
c6 = a5 @ b5
detc6 = np.linalg.det(c6)
c7 = b5 @ a5
detc7 =  np.linalg.det(c7)
detc6, detc7
# Out:
# (0.9999999999999998, 1.0)
